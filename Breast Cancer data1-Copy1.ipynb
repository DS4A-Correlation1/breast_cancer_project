# %%
import pandas as pd
import numpy as np
import os
from glob import glob
import itertools
import fnmatch
import random
import seaborn as sns
import cv2
import sklearn
from sklearn import model_selection
from sklearn.model_selection import train_test_split, KFold, cross_val_score, StratifiedKFold, learning_curve, GridSearchCV
from sklearn.metrics import confusion_matrix, make_scorer, accuracy_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
import tensorflow.keras
from tensorflow.keras.preprocessing import image
from keras import backend as K
from keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from keras.preprocessing.image import ImageDataGenerator
from keras.utils.np_utils import to_categorical
from keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization, Conv2D, MaxPool2D, MaxPooling2D
# %matplotlib inline
import glob
# Out:
# Using TensorFlow backend.

# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'
import pandas as pd
import numpy as np
from glob import glob
import matplotlib.pylab as plt
import sys
from PIL import Image
sys.modules['Image'] = Image

# %% [markdown]
# # Dataset

# %%
all_data=glob("/Users/weiminliu/Downloads/archive/**/*.png",recursive = True)

# %%
for e in all_data[:3]:
    print(e)

#create empty list
cancer=[] 
no_cancer=[]

#create loop
for d in all_data:
    if d[-5]=="0":
        no_cancer.append(d)
    elif d[-5] =='1':
        cancer.append(d)
# Out:
# /Users/weiminliu/Downloads/archive/9036/0/9036_idx5_x1051_y2401_class0.png
# /Users/weiminliu/Downloads/archive/9036/0/9036_idx5_x2951_y951_class0.png
# /Users/weiminliu/Downloads/archive/9036/0/9036_idx5_x3001_y1451_class0.png

# %%
plt.figure(figsize=(10,10))
for e in range(1,len(no_cancer[:12])):
    plt.subplot(5,5,e+4)
    plt.axis('off')
    plt.title('IDC (-)')
    imt = image.load_img(no_cancer[e],target_size=(100,100))
    imt = image.img_to_array(imt)                     
    plt.imshow(imt.astype('uint8'))
    
    
for e in range(1,len(cancer[:12])):
    plt.subplot(5,5,e)
    plt.axis('off')
    plt.title('IDC (+)')
    imag = image.load_img(cancer[e],target_size=(100,100))
    imag = image.img_to_array(imag)                     
    plt.imshow(imag.astype('uint8'))

# %% [markdown]
# ## Preprocess

# %%
from matplotlib.image import imread
import cv2
non_image_cancer=[]
image_cancer=[]

# %%
#sample
cancer= random.sample(cancer, 20000)
no_cancer= random.sample(no_cancer, 20000)

# %%
#creating loop & label 
for g in no_cancer:
    number_image=cv2.imread(g,cv2.IMREAD_COLOR)

    image_size=cv2.resize(number_image,(50,50),interpolation = cv2.INTER_LINEAR)
    non_image_cancer.append([image_size,0])

# %%
# creating loop &label 
for g in cancer:
    number_image=cv2.imread(g,cv2.IMREAD_COLOR)
    image_size=cv2.resize(number_image,(50,50),interpolation = cv2.INTER_LINEAR)
    image_cancer.append([image_size,1])

# %%
# create empty list
x=[]
y=[]

# %%
#transform to array
import numpy as np
breast_image_array=np.concatenate((image_cancer,non_image_cancer))
# Out:
# <string>:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.

# %%
#import random
import random
random.shuffle(breast_image_array)
for feature,label in breast_image_array:
    x.append(feature)
    y.append(label)

# %%
#create array to see shape
x=np.array(x)
y=np.array(y)
x.shape
# Out:
# (40000, 50, 50, 3)

# %%
y.shape
# Out:
# (40000,)

# %% [markdown]
# ## Split train and test

# %%
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical

X_train, X_predict, y_train, y_true = train_test_split(x, y, test_size = 0.3)
rate = 0.5
num = int(x.shape[0] * rate)

X_test = X_train[num:]
X_train = X_train[:num]

y_test = y_train[num:]
y_train = y_train[:num]

y_train = to_categorical(y_train, 2)
y_test = to_categorical(y_test, 2)
y_true = to_categorical(y_true, 2)

print('X_train shape : {}' .format(X_train.shape))
print('X_test shape : {}' .format(X_test.shape))
print('X_predict shape : {}' .format(X_predict.shape))
print('y_train shape : {}' .format(y_train.shape))
print('y_test shape : {}' .format(y_test.shape))
# Out:
# X_train shape : (20000, 50, 50, 3)
# X_test shape : (8000, 50, 50, 3)
# X_predict shape : (12000, 50, 50, 3)
# y_train shape : (20000, 2)
# y_test shape : (8000, 2)

# %%
def plot_model_parameters(history): 
    plt.figure(1, figsize = (20, 6))
    plt.subplot(121)
    plt.plot(history.history['loss'])
    # plt.plot(history.history['val_loss'])
    plt.title('Model Loss', fontsize = 16)
    plt.ylabel('loss', fontsize = 16)
    plt.xlabel('epoch', fontsize = 16)
    plt.xticks(fontsize = 14)
    plt.yticks(fontsize = 14)
    
    plt.subplot(122)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model Accuracy', fontsize=16)
    plt.ylabel('accuracy', fontsize = 16)
    plt.xlabel('epoch', fontsize = 16)
    plt.xticks(fontsize = 14)
    plt.yticks(fontsize = 14)
    plt.legend(['train', 'test'], loc='upper left', fontsize = 16)
    
    plt.show()
    plt.savefig('loss_and_accuracy', dpi = 300)

# %%
from tensorflow.keras.applications.vgg16 import VGG16

# Load in VGG-16 model with weights pre-trained on ImageNet
vgg_model = VGG16(weights='imagenet', include_top=False, input_shape=(50, 50, 3))

# Freeze four convolution blocks
for layer in vgg_model.layers[:15]:
    layer.trainable = False

# Make sure the correct layers are frozen
for i, layer in enumerate(vgg_model.layers):
    print(i, layer.name, layer.trainable)
# Out:
# 2021-10-18 16:16:30.793371: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-10-18 16:16:30.798410: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 8. Tune using inter_op_parallelism_threads for best performance.
# 0 input_1 False
# 1 block1_conv1 False
# 2 block1_conv2 False
# 3 block1_pool False
# 4 block2_conv1 False
# 5 block2_conv2 False
# 6 block2_pool False
# 7 block3_conv1 False
# 8 block3_conv2 False
# 9 block3_conv3 False
# 10 block3_pool False
# 11 block4_conv1 False
# 12 block4_conv2 False
# 13 block4_conv3 False
# 14 block4_pool False
# 15 block5_conv1 True
# 16 block5_conv2 True
# 17 block5_conv3 True
# 18 block5_pool True

# %%
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.models import Model

x = vgg_model.output
x = Flatten()(x) # Flatten dimensions to for use in FC layers
x = Dense(512, activation='relu')(x)
x = Dropout(0.5)(x) # Dropout layer to reduce overfitting
x = Dense(256, activation = 'relu')(x)
x = Dense(2, activation = 'softmax')(x) # Softmax for multiclass

transfer_model = Model(inputs=vgg_model.input, outputs = x)

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.callbacks import ModelCheckpoint

lr_reduce = ReduceLROnPlateau(monitor = 'val_accuracy', 
                              factor = 0.6, 
                              patience = 8, 
                              verbose = 1, 
                              mode = 'max', 
                              min_lr = 5e-5)

checkpoint = ModelCheckpoint('vgg16_finetune.h15', 
                             monitor = 'val_accuracy', 
                             mode = 'max', 
                             save_best_only = True, 
                             verbose = 1)

# %%
from tensorflow.keras import layers, models, Model, optimizers

learning_rate = 5e-5

transfer_model.compile(loss = "categorical_crossentropy", 
                       optimizer = optimizers.Adam(lr = learning_rate), 
                       metrics = ["accuracy"])

history_vgg = transfer_model.fit(X_train, y_train, batch_size = 20, 
                                 epochs = 50, validation_data = (X_test,y_test), callbacks=[lr_reduce,checkpoint])
# Out:
# Train on 20000 samples, validate on 8000 samples
# Epoch 1/50
# 19980/20000 [============================>.] - ETA: 1s - loss: 0.4029 - accuracy: 0.8407
# Epoch 00001: val_accuracy improved from -inf to 0.86325, saving model to vgg16_finetune.h15
# WARNING:tensorflow:From /Users/weiminliu/opt/anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1781: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# 2021-10-18 16:40:13.755013: W tensorflow/python/util/util.cc:299] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: vgg16_finetune.h15/assets
# 20000/20000 [==============================] - 1354s 68ms/sample - loss: 0.4027 - accuracy: 0.8408 - val_loss: 0.2996 - val_accuracy: 0.8633
# Epoch 2/50
# 19980/20000 [============================>.] - ETA: 1s - loss: 0.2945 - accuracy: 0.8571
# Epoch 00002: val_accuracy improved from 0.86325 to 0.87138, saving model to vgg16_finetune.h15
# INFO:tensorflow:Assets written to: vgg16_finetune.h15/assets
# 20000/20000 [==============================] - 1377s 69ms/sample - loss: 0.2944 - accuracy: 0.8572 - val_loss: 0.2646 - val_accuracy: 0.8714
# Epoch 3/50
# 19980/20000 [============================>.] - ETA: 1s - loss: 0.2484 - accuracy: 0.8859
# Epoch 00003: val_accuracy improved from 0.87138 to 0.89487, saving model to vgg16_finetune.h15
# INFO:tensorflow:Assets written to: vgg16_finetune.h15/assets
# 20000/20000 [==============================] - 1371s 69ms/sample - loss: 0.2483 - accuracy: 0.8860 - val_loss: 0.2427 - val_accuracy: 0.8949
# Epoch 4/50
# 19980/20000 [============================>.] - ETA: 1s - loss: 0.2072 - accuracy: 0.9126
# Epoch 00004: val_accuracy did not improve from 0.89487
# 20000/20000 [==============================] - 1356s 68ms/sample - loss: 0.2071 - accuracy: 0.9125 - val_loss: 0.2499 - val_accuracy: 0.8726
# Epoch 5/50
# 19980/20000 [============================>.] - ETA: 0s - loss: 0.1625 - accuracy: 0.9295
# Epoch 00005: val_accuracy improved from 0.89487 to 0.90700, saving model to vgg16_finetune.h15
# INFO:tensorflow:Assets written to: vgg16_finetune.h15/assets
# 20000/20000 [==============================] - 1311s 66ms/sample - loss: 0.1625 - accuracy: 0.9295 - val_loss: 0.2661 - val_accuracy: 0.9070
# Epoch 6/50
# 19980/20000 [============================>.] - ETA: 0s - loss: 0.1259 - accuracy: 0.9484
# Epoch 00006: val_accuracy improved from 0.90700 to 0.91612, saving model to vgg16_finetune.h15
# INFO:tensorflow:Assets written to: vgg16_finetune.h15/assets
# 20000/20000 [==============================] - 1310s 66ms/sample - loss: 0.1258 - accuracy: 0.9485 - val_loss: 0.2683 - val_accuracy: 0.9161
# Epoch 7/50
# 19980/20000 [============================>.] - ETA: 0s - loss: 0.0922 - accuracy: 0.9633
# Epoch 00007: val_accuracy improved from 0.91612 to 0.92025, saving model to vgg16_finetune.h15
# INFO:tensorflow:Assets written to: vgg16_finetune.h15/assets
# 20000/20000 [==============================] - 1312s 66ms/sample - loss: 0.0922 - accuracy: 0.9633 - val_loss: 0.2844 - val_accuracy: 0.9202
# Epoch 8/50
# 19980/20000 [============================>.] - ETA: 0s - loss: 0.0681 - accuracy: 0.9737
# Epoch 00008: val_accuracy did not improve from 0.92025
# 20000/20000 [==============================] - 1310s 65ms/sample - loss: 0.0681 - accuracy: 0.9736 - val_loss: 0.3191 - val_accuracy: 0.9124
# Epoch 9/50
# 19980/20000 [============================>.] - ETA: 0s - loss: 0.0538 - accuracy: 0.9789
# Epoch 00009: val_accuracy improved from 0.92025 to 0.92575, saving model to vgg16_finetune.h15
# INFO:tensorflow:Assets written to: vgg16_finetune.h15/assets
# 20000/20000 [==============================] - 1311s 66ms/sample - loss: 0.0538 - accuracy: 0.9789 - val_loss: 0.3647 - val_accuracy: 0.9258
# Epoch 10/50
# 19980/20000 [============================>.] - ETA: 0s - loss: 0.0351 - accuracy: 0.9865
# Epoch 00010: val_accuracy improved from 0.92575 to 0.92663, saving model to vgg16_finetune.h15
# INFO:tensorflow:Assets written to: vgg16_finetune.h15/assets
# 20000/20000 [==============================] - 1313s 66ms/sample - loss: 0.0350 - accuracy: 0.9865 - val_loss: 0.4205 - val_accuracy: 0.9266
# Epoch 11/50
# 19980/20000 [============================>.] - ETA: 0s - loss: 0.0324 - accuracy: 0.9877
# Epoch 00011: val_accuracy did not improve from 0.92663
# 20000/20000 [==============================] - 1313s 66ms/sample - loss: 0.0324 - accuracy: 0.9877 - val_loss: 0.4215 - val_accuracy: 0.9258
# Epoch 12/50
# 19980/20000 [============================>.] - ETA: 0s - loss: 0.0257 - accuracy: 0.9903
# Epoch 00012: val_accuracy did not improve from 0.92663
# 20000/20000 [==============================] - 1322s 66ms/sample - loss: 0.0257 - accuracy: 0.9904 - val_loss: 0.4906 - val_accuracy: 0.9234
# Epoch 13/50
# 19980/20000 [============================>.] - ETA: 0s - loss: 0.0279 - accuracy: 0.9914
# Epoch 00013: val_accuracy improved from 0.92663 to 0.93075, saving model to vgg16_finetune.h15
# INFO:tensorflow:Assets written to: vgg16_finetune.h15/assets
# 20000/20000 [==============================] - 1334s 67ms/sample - loss: 0.0278 - accuracy: 0.9914 - val_loss: 0.5377 - val_accuracy: 0.9308
# Epoch 14/50
# 19980/20000 [============================>.] - ETA: 0s - loss: 0.0284 - accuracy: 0.9900
# Epoch 00014: val_accuracy did not improve from 0.93075
# 20000/20000 [==============================] - 1330s 66ms/sample - loss: 0.0288 - accuracy: 0.9900 - val_loss: 0.3430 - val_accuracy: 0.9298
# Epoch 15/50
# 19980/20000 [============================>.] - ETA: 0s - loss: 0.0165 - accuracy: 0.9946
# Epoch 00015: val_accuracy improved from 0.93075 to 0.93275, saving model to vgg16_finetune.h15
# INFO:tensorflow:Assets written to: vgg16_finetune.h15/assets
# 20000/20000 [==============================] - 1316s 66ms/sample - loss: 0.0165 - accuracy: 0.9946 - val_loss: 0.5474 - val_accuracy: 0.9327
# Epoch 16/50
# 19980/20000 [============================>.] - ETA: 0s - loss: 0.0228 - accuracy: 0.9926
# Epoch 00016: val_accuracy did not improve from 0.93275
# 20000/20000 [==============================] - 1328s 66ms/sample - loss: 0.0228 - accuracy: 0.9926 - val_loss: 0.4605 - val_accuracy: 0.9260
# Epoch 17/50
# 19980/20000 [============================>.] - ETA: 1s - loss: 0.0196 - accuracy: 0.9936
# Epoch 00017: val_accuracy did not improve from 0.93275
# 20000/20000 [==============================] - 1355s 68ms/sample - loss: 0.0195 - accuracy: 0.9937 - val_loss: 0.4305 - val_accuracy: 0.9275
# Epoch 18/50
# 19980/20000 [============================>.] - ETA: 1s - loss: 0.0163 - accuracy: 0.9941
# Epoch 00018: val_accuracy did not improve from 0.93275
# 20000/20000 [==============================] - 1358s 68ms/sample - loss: 0.0163 - accuracy: 0.9941 - val_loss: 0.5525 - val_accuracy: 0.9287
# Epoch 19/50
# 19980/20000 [============================>.] - ETA: 1s - loss: 0.0145 - accuracy: 0.9956
# Epoch 00019: val_accuracy did not improve from 0.93275
# 20000/20000 [==============================] - 1355s 68ms/sample - loss: 0.0146 - accuracy: 0.9955 - val_loss: 0.4339 - val_accuracy: 0.9220
# Epoch 20/50
# 19980/20000 [============================>.] - ETA: 1s - loss: 0.0124 - accuracy: 0.9957
# Epoch 00020: val_accuracy did not improve from 0.93275
# 20000/20000 [==============================] - 1353s 68ms/sample - loss: 0.0124 - accuracy: 0.9958 - val_loss: 0.4404 - val_accuracy: 0.9299
# Epoch 21/50
# 19980/20000 [============================>.] - ETA: 0s - loss: 0.0149 - accuracy: 0.9953
# Epoch 00021: val_accuracy did not improve from 0.93275
# 20000/20000 [==============================] - 1333s 67ms/sample - loss: 0.0152 - accuracy: 0.9953 - val_loss: 0.4266 - val_accuracy: 0.9283
# Epoch 22/50
# 19980/20000 [============================>.] - ETA: 0s - loss: 0.0155 - accuracy: 0.9951
# Epoch 00022: val_accuracy did not improve from 0.93275
# 20000/20000 [==============================] - 1322s 66ms/sample - loss: 0.0155 - accuracy: 0.9952 - val_loss: 0.4051 - val_accuracy: 0.9178
# Epoch 23/50
# 19980/20000 [============================>.] - ETA: 0s - loss: 0.0136 - accuracy: 0.9957
# Epoch 00023: val_accuracy did not improve from 0.93275
# 20000/20000 [==============================] - 1334s 67ms/sample - loss: 0.0136 - accuracy: 0.9958 - val_loss: 0.8044 - val_accuracy: 0.9219
# Epoch 24/50
# 19980/20000 [============================>.] - ETA: 0s - loss: 0.0125 - accuracy: 0.9956
# Epoch 00024: val_accuracy did not improve from 0.93275
# 20000/20000 [==============================] - 1325s 66ms/sample - loss: 0.0125 - accuracy: 0.9956 - val_loss: 0.4825 - val_accuracy: 0.9289
# Epoch 25/50
# 19980/20000 [============================>.] - ETA: 0s - loss: 0.0123 - accuracy: 0.9965
# Epoch 00025: val_accuracy did not improve from 0.93275
# 20000/20000 [==============================] - 1317s 66ms/sample - loss: 0.0123 - accuracy: 0.9965 - val_loss: 0.4340 - val_accuracy: 0.9279
# Epoch 26/50
# 19980/20000 [============================>.] - ETA: 0s - loss: 0.0106 - accuracy: 0.9976
# Epoch 00026: val_accuracy did not improve from 0.93275
# 20000/20000 [==============================] - 1318s 66ms/sample - loss: 0.0106 - accuracy: 0.9976 - val_loss: 0.5000 - val_accuracy: 0.9281
# Epoch 27/50
# 19980/20000 [============================>.] - ETA: 0s - loss: 0.0068 - accuracy: 0.9984
# Epoch 00027: val_accuracy did not improve from 0.93275
# 20000/20000 [==============================] - 1327s 66ms/sample - loss: 0.0069 - accuracy: 0.9984 - val_loss: 0.4430 - val_accuracy: 0.9252
# Epoch 28/50
# 19980/20000 [============================>.] - ETA: 0s - loss: 0.0176 - accuracy: 0.9947
# Epoch 00028: val_accuracy did not improve from 0.93275
# 20000/20000 [==============================] - 1315s 66ms/sample - loss: 0.0176 - accuracy: 0.9947 - val_loss: 0.4572 - val_accuracy: 0.9255
# Epoch 29/50
# 19980/20000 [============================>.] - ETA: 0s - loss: 0.0154 - accuracy: 0.9949
# Epoch 00029: val_accuracy did not improve from 0.93275
# 20000/20000 [==============================] - 1311s 66ms/sample - loss: 0.0154 - accuracy: 0.9949 - val_loss: 0.4864 - val_accuracy: 0.9273
# Epoch 30/50
# 19980/20000 [============================>.] - ETA: 0s - loss: 0.0122 - accuracy: 0.9963
# Epoch 00030: val_accuracy did not improve from 0.93275
# 20000/20000 [==============================] - 1311s 66ms/sample - loss: 0.0122 - accuracy: 0.9963 - val_loss: 0.4941 - val_accuracy: 0.9298
# Epoch 31/50
# 19980/20000 [============================>.] - ETA: 0s - loss: 0.0123 - accuracy: 0.9962
# Epoch 00031: val_accuracy did not improve from 0.93275
# 20000/20000 [==============================] - 1312s 66ms/sample - loss: 0.0123 - accuracy: 0.9962 - val_loss: 0.6126 - val_accuracy: 0.9264
# Epoch 32/50
# 19980/20000 [============================>.] - ETA: 0s - loss: 0.0067 - accuracy: 0.9977
# Epoch 00032: val_accuracy did not improve from 0.93275
# 20000/20000 [==============================] - 1310s 66ms/sample - loss: 0.0067 - accuracy: 0.9977 - val_loss: 0.6723 - val_accuracy: 0.9316
# Epoch 33/50
# 19980/20000 [============================>.] - ETA: 0s - loss: 0.0129 - accuracy: 0.9969
# Epoch 00033: val_accuracy did not improve from 0.93275
# 20000/20000 [==============================] - 1311s 66ms/sample - loss: 0.0130 - accuracy: 0.9969 - val_loss: 0.7729 - val_accuracy: 0.9212
# Epoch 34/50
# 19980/20000 [============================>.] - ETA: 0s - loss: 0.0102 - accuracy: 0.9969
# Epoch 00034: val_accuracy did not improve from 0.93275
# 20000/20000 [==============================] - 1312s 66ms/sample - loss: 0.0102 - accuracy: 0.9969 - val_loss: 0.4763 - val_accuracy: 0.9299
# Epoch 35/50
# 19980/20000 [============================>.] - ETA: 0s - loss: 0.0122 - accuracy: 0.9964
# Epoch 00035: val_accuracy did not improve from 0.93275
# 20000/20000 [==============================] - 1312s 66ms/sample - loss: 0.0122 - accuracy: 0.9965 - val_loss: 0.5092 - val_accuracy: 0.9287
# Epoch 36/50
# 19980/20000 [============================>.] - ETA: 0s - loss: 0.0062 - accuracy: 0.9980
# Epoch 00036: val_accuracy did not improve from 0.93275
# 20000/20000 [==============================] - 1312s 66ms/sample - loss: 0.0062 - accuracy: 0.9980 - val_loss: 0.6022 - val_accuracy: 0.9280
# Epoch 37/50
# 19980/20000 [============================>.] - ETA: 0s - loss: 0.0083 - accuracy: 0.9975
# Epoch 00037: val_accuracy did not improve from 0.93275
# 20000/20000 [==============================] - 1311s 66ms/sample - loss: 0.0083 - accuracy: 0.9976 - val_loss: 0.5908 - val_accuracy: 0.9308
# Epoch 38/50
# 19980/20000 [============================>.] - ETA: 0s - loss: 0.0110 - accuracy: 0.9974
# Epoch 00038: val_accuracy did not improve from 0.93275
# 20000/20000 [==============================] - 1313s 66ms/sample - loss: 0.0110 - accuracy: 0.9974 - val_loss: 0.4370 - val_accuracy: 0.9302
# Epoch 39/50
# 19980/20000 [============================>.] - ETA: 0s - loss: 0.0092 - accuracy: 0.9974
# Epoch 00039: val_accuracy did not improve from 0.93275
# 20000/20000 [==============================] - 1313s 66ms/sample - loss: 0.0092 - accuracy: 0.9974 - val_loss: 0.4227 - val_accuracy: 0.9311
# Epoch 40/50
# 19980/20000 [============================>.] - ETA: 0s - loss: 0.0056 - accuracy: 0.9987
# Epoch 00040: val_accuracy did not improve from 0.93275
# 20000/20000 [==============================] - 1313s 66ms/sample - loss: 0.0056 - accuracy: 0.9987 - val_loss: 0.5435 - val_accuracy: 0.9281
# Epoch 41/50
# 19980/20000 [============================>.] - ETA: 0s - loss: 0.0105 - accuracy: 0.9969
# Epoch 00041: val_accuracy did not improve from 0.93275
# 20000/20000 [==============================] - 1313s 66ms/sample - loss: 0.0105 - accuracy: 0.9969 - val_loss: 0.4116 - val_accuracy: 0.9266
# Epoch 42/50
# 19980/20000 [============================>.] - ETA: 0s - loss: 0.0123 - accuracy: 0.9962
# Epoch 00042: val_accuracy did not improve from 0.93275
# 20000/20000 [==============================] - 1314s 66ms/sample - loss: 0.0123 - accuracy: 0.9962 - val_loss: 0.4053 - val_accuracy: 0.9302
# Epoch 43/50
# 19980/20000 [============================>.] - ETA: 0s - loss: 0.0103 - accuracy: 0.9968
# Epoch 00043: val_accuracy did not improve from 0.93275
# 20000/20000 [==============================] - 1313s 66ms/sample - loss: 0.0103 - accuracy: 0.9969 - val_loss: 0.4302 - val_accuracy: 0.9301
# Epoch 44/50
# 19980/20000 [============================>.] - ETA: 0s - loss: 0.0038 - accuracy: 0.9993
# Epoch 00044: val_accuracy did not improve from 0.93275
# 20000/20000 [==============================] - 1314s 66ms/sample - loss: 0.0038 - accuracy: 0.9993 - val_loss: 0.4860 - val_accuracy: 0.9327
# Epoch 45/50
# 19980/20000 [============================>.] - ETA: 0s - loss: 0.0078 - accuracy: 0.9976
# Epoch 00045: val_accuracy did not improve from 0.93275
# 20000/20000 [==============================] - 1314s 66ms/sample - loss: 0.0078 - accuracy: 0.9976 - val_loss: 0.6378 - val_accuracy: 0.9243
# Epoch 46/50
# 19980/20000 [============================>.] - ETA: 0s - loss: 0.0071 - accuracy: 0.9978
# Epoch 00046: val_accuracy did not improve from 0.93275
# 20000/20000 [==============================] - 1313s 66ms/sample - loss: 0.0071 - accuracy: 0.9979 - val_loss: 0.3990 - val_accuracy: 0.9265
# Epoch 47/50
# 19980/20000 [============================>.] - ETA: 0s - loss: 0.0047 - accuracy: 0.9987
# Epoch 00047: val_accuracy did not improve from 0.93275
# 20000/20000 [==============================] - 1314s 66ms/sample - loss: 0.0047 - accuracy: 0.9987 - val_loss: 0.5100 - val_accuracy: 0.9284
# Epoch 48/50
# 19980/20000 [============================>.] - ETA: 0s - loss: 0.0087 - accuracy: 0.9979
# Epoch 00048: val_accuracy did not improve from 0.93275
# 20000/20000 [==============================] - 1312s 66ms/sample - loss: 0.0087 - accuracy: 0.9980 - val_loss: 0.6110 - val_accuracy: 0.9283
# Epoch 49/50
# 19980/20000 [============================>.] - ETA: 0s - loss: 0.0099 - accuracy: 0.9976
# Epoch 00049: val_accuracy did not improve from 0.93275
# 20000/20000 [==============================] - 1313s 66ms/sample - loss: 0.0099 - accuracy: 0.9976 - val_loss: 0.4295 - val_accuracy: 0.9229
# Epoch 50/50
# 19980/20000 [============================>.] - ETA: 0s - loss: 0.0091 - accuracy: 0.9976
# Epoch 00050: val_accuracy did not improve from 0.93275
# 20000/20000 [==============================] - 1315s 66ms/sample - loss: 0.0091 - accuracy: 0.9976 - val_loss: 0.5652 - val_accuracy: 0.9285

# %%
plot_model_parameters(history_vgg)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
y_pred = transfer_model.predict(X_test)
y_pred_labels = np.argmax(y_pred, axis = 1)
y_test_labels = np.argmax(y_test, axis = 1)
cm = confusion_matrix(y_test_labels, y_pred_labels)
disp = ConfusionMatrixDisplay(confusion_matrix = cm, display_labels = ['no cancer', 'cancer'])
disp.plot()
plt.show()
plt.savefig('confusion_matrix', dpi = 300)
